# %%
import pandas as pd
from sklearn.decomposition import SparsePCA, TruncatedSVD, LatentDirichletAllocation, NMF

n_components = 50
svd_ = TruncatedSVD(n_components=n_components, random_state=1337)
a1 = pd.read_csv('train_img_features.csv')
a2 = pd.read_csv('test_img_features.csv')
a = pd.concat([a1,a2], axis=0)

svd_col = svd_.fit_transform((a.drop(['PetID'], axis=1)).values)
svd_col = pd.DataFrame(svd_col)

# %%
svd_col.shape
b = svd_col.add_prefix('IMG_SVD_')

# %%
a
a.drop(['index'], axis=1, inplace = True)
a
# Out:
#            PetID
# 0      86e1089a3
# 1      6296e909a
# 2      3422e4906
# 3      5842f1ff5
# 4      850a43f90
# 5      d24c30b4b
# 6      1caa6fcdb
# 7      97aa9eeac
# 8      c06d167ca
# 9      7a0942d61
# 10     8b693ca84
# 11     8e76c8e39
# 12     aaedd873d
# 13     4a9793dfb
# 14     c02be41e6
# 15     1fd342e17
# 16     b38a74866
# 17     f9d07d5fa
# 18     1c92ce464
# 19     b10e7605a
# 20     6436c1a59
# 21     234a5a54c
# 22     1bc0f89d8
# 23     1bf24d8be
# 24     988988d5b
# 25     cf7d3eec0
# 26     85fc3c314
# 27     efbf1703a
# 28     7843a9dca
# 29     d341fbfd6
# ...          ...
# 18911  4586798a6
# 18912  e5ec7709d
# 18913  fa0b958ae
# 18914  85fda19ab
# 18915  d6a2fa83e
# 18916  08f25f7da
# 18917  a159e317f
# 18918  09582e51b
# 18919  0c9cc3c3d
# 18920  fd6a10dd8
# 18921  3b22e5249
# 18922  62abaa505
# 18923  d274a7103
# 18924  4f244a307
# 18925  34e4c214d
# 18926  67b8ae43b
# 18927  285a40127
# 18928  ce637df13
# 18929  e07d8debe
# 18930  5c23692a4
# ...

# %%
a
# Out:
#           PetID         0         1         2         3         4         5  \
# 0     86e1089a3  0.002000  0.167800  0.019715  0.015896  0.068162  0.002216
# 1     6296e909a  0.002858  0.107450  0.019916  0.023482  0.174765  0.002297
# 2     3422e4906  0.002734  0.072015  0.024455  0.018021  0.154207  0.001946
# 3     5842f1ff5  0.002106  0.274519  0.054815  0.013727  0.089969  0.001650
# 4     850a43f90  0.002185  0.174022  0.044818  0.016244  0.169775  0.002075
# 5     d24c30b4b  0.002288  0.046608  0.038229  0.009884  0.172019  0.003591
# 6     1caa6fcdb  0.002559  0.159602  0.031026  0.013435  0.071857  0.002615
# 7     97aa9eeac  0.002233  0.060228  0.023051  0.017436  0.118636  0.002586
# 8     c06d167ca  0.002346  0.372302  0.066635  0.023606  0.075638  0.002161
# 9     7a0942d61  0.002051  0.158108  0.054486  0.010553  0.161805  0.002087
# 10    8b693ca84  0.002435  0.205554  0.032817  0.021864  0.030360  0.001632
# ...

# %%
b = svd_col.add_prefix('IMG_SVD_')
img_features = pd.concat([a, b], axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-60-8434d77ffb48> in <module>
#       1 b = svd_col.add_prefix('IMG_SVD_')
# ----> 2 img_features = pd.concat([a, b], axis=1)
#
# D:\software\anaconda\envs\python36\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# D:\software\anaconda\envs\python36\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     376         self.copy = copy
#     377
# ...

# %%
img_features.to_csv('img_features.csv')
